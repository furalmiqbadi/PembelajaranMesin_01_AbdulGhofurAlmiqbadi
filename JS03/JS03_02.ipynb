# %% [markdown]
# <a href="https://colab.research.google.com/github/furalmiqbadi/PembelajaranMesin_01_AbdulGhofurAlmiqbadi/blob/main/JS03/JS03_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Langkah 0 - Siapkan Corpus

# %%
	corpus = [
	    'the house had a tiny little mouse',
	    'the cat saw the mouse',
	    'the mouse ran away from the house',
	    'the cat finally ate the mouse',
	    'the end of the mouse story'
	]

# %% [markdown]
# # Langkah 1 - Buat Model TF-IDF

# %%
	from sklearn.feature_extraction.text import TfidfVectorizer

	# Inisiasi obyek TFidfVectorizer
	vect = TfidfVectorizer(stop_words='english')

	# Pembobotan TF-IDF
	resp = vect.fit_transform(corpus)

	# Cetak hasil
	print(resp)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 18 stored elements and shape (5, 12)>
#   Coords	Values
#   (0, 5)	0.47557510189256375
#   (0, 11)	0.5894630806320427
#   (0, 6)	0.5894630806320427
#   (0, 7)	0.2808823162882302
#   (1, 7)	0.3477147117091919
#   (1, 2)	0.5887321837696324
#   (1, 9)	0.7297183669435993
#   (2, 5)	0.47557510189256375
#   (2, 7)	0.2808823162882302
#   (2, 8)	0.5894630806320427
#   (2, 1)	0.5894630806320427
#   (3, 7)	0.2808823162882302
#   (3, 2)	0.47557510189256375
#   (3, 4)	0.5894630806320427
#   (3, 0)	0.5894630806320427
#   (4, 7)	0.3193023297639811
#   (4, 3)	0.6700917930430479
#   (4, 10)	0.6700917930430479

# %% [markdown]
# # Langkah 2 - Cek Kata yang Digunakan

# %%
print(vect.get_feature_names_out())
# Out:
# ['ate' 'away' 'cat' 'end' 'finally' 'house' 'little' 'mouse' 'ran' 'saw'
#  'story' 'tiny']
